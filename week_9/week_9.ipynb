# %% [markdown]
# # 웹 크롤링

# %%
import urllib.request
import bs4
nateUrl = "https://www.nate.com"
htmlObject = urllib.request.urlopen(nateUrl)
bsObject = bs4.BeautifulSoup(htmlObject, 'html.parser')
print(bsObject)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="//www.nate.com/" name="msapplication-starturl"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="" name="nate:title"/>
# <meta content="네이트 이슈UP" name="nate:description"/>
# <meta content="네이트 홈" name="nate:site_name"/>
# <meta content="https://www.nate.com/" name="nate:url"/>
# <meta content="" name="nate:image"/>
# <meta content="새로워진 네이트에서 당신의 오늘을 만나보세요" name="description"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="네이트" property="og:title"/>
# <meta content="https://www.nate.com/" property="og:url"/>
# <meta content="https://main.nateimg.co.kr/img/v7/OpenGraphTag_nate_240x240.png" property="og:image"/>
# <meta content="새로워진 네이트에서 당신의 오늘을 만나보세요" property="og:description"/>
# <title>네이트</title>
# <link href="/css/common.min.css?v=202502251421_01" rel="stylesheet" type="text/css"/>
# <link href="//main.nateimg.co.kr/img/v7/favicon_32.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://www.nate.com" rel="canonical"/>
# <script src="/js/common/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	var isSvc = true; var isInfoAjax = true;
# 	var make = 't';
# 	var isMakeLogin = '';
# 	var host = 'www.nate.com';
# 	var isNateLogin = (isMakeLogin == "Y") ? true : false;
# 	var myId = "";
# 	var iSvcSeq  ='3';
# 	var iSvcSeqB ='3';
# 	var iSvcSeqC ='1';
# 	var currentWeatherIndex = [0,11,8];
# 	var iSvcSeqW = iSvcSeqB;
# 	var isCommsbarOpen = ('N' == 'Y') ? true : false;
# 	var loginType = '';
# 	var isiPad = (navigator.userAgent.toUpperCase().indexOf("IPAD") !== -1);
# 	var isGalaxyTab = (navigator.userAgent.toUpperCase().indexOf("SHW-M180") !== -1); // GT-P1000
# 	var isGalaxyTab10 = (navigator.userAgent.toUpperCase().indexOf("SHW-M380") !== -1);
# 	var isTablet = (isiPad == true || isGalaxyTab == true || isGalaxyTab10 == true);
# 	if (isTablet)
# 	{
# 	    document.write('<link rel="apple-touch-icon-precomposed" href="//main.nateimg.co.kr/img/nate_144.png" />');
# 	}
# 	var loginBoxName 	= "아이디 or @이하 모두 입력";
# 	var hostInfo 	 	= (host.length > 0) ? '//' + host : '';
#
# 	var verTravel 		= '202505021306';
# 	var verLife 		= '202505021306';
# 	var verIssueFun		= '202505021306';
# 	var verIssue04 		= '202505021302';
# 	var verIssue05 		= '202505021302';
# 	var verIssue06 		= '202505021302';
# 	var verIssue07 		= '202505021302';
#
# 	var verNateTV			= '202505021313';
# 	var verIssueKeyword		= '202505021310';
# 	var verToonNBook		= '202505021307';
# 	var verShortFormBest	= '202505021303';
# 	var verWeather			= '202505021258';
# 	var verTodayBox			= '202505021217';
# 	var verCarTech			= '202505021306';
#
# 	var verRanking06		= '202505021303';
# 	var verGnbRoll			= '202505021302';
# 	var verNewsBox 			= '202505021312';
# 	var verShopRecomm		= '202505021311';
#
# 	var verPannTotal		= '202505021309';
# 	var verPannWomanLife	= '202505021310';
# 	var verPannTeens		= '202505021310';
# 	var verPannEnter		= '202505021310';
# 	var verTodayKeyword 	= '202503251436';
# 	var verWorkLife			= '202505021310';
# 	var verKeywordAd		= '202505021218';
# 	var verAdFunFun			= '202505021306';
# 	var verBizSearch 		= '202504171838';
# 	var verPann01 			= '201907240835';
# 	var verPann02 			= '201907240835';
#
# 	var shoppingInspection 		= 'N';
# 	var isEmergencyShoppingTab 	= 'N';
# 	var isAutoRefresh 			= true;
# 	var isChangeTab 			= false;
# 	var nateAwardsStat			= '';
# 	var isViewKeywordRank		= 'N';
# 	var isEmergencyToonNBookTab = 'N';
#
# 	//]]>
# 	</script>
# <script src="/js/common/nate_general_v20170627.js?v=202504221005_15" type="text/javascript"></script>
# <script src="/js/common/ac_v6.js?v=20250410_01" type="text/javascript"></script>
# <script src="/js/common/nate_logout_v20170627.js?v=202001141024_01" type="text/javascript"></script>
# <script type="text/javascript">
# 		 //<![CDATA[
# 			var bLogout = false;
# 	    	if (isLogout()) { fillLogout(); }
# 		 //]]>
# 		</script>
# <script src="/js/common/swiper.min.js?v=1" type="text/javascript"></script>
# </link></head>
# <body>
# <script type="text/javascript">
# 	 //<![CDATA[
# 		pageEnd2('st');
# 	 //]]>
# 	</script>
# <div id="mainContainer">
# <div class="area_access">
# <h2>네이트 메인페이지 주요 내용 바로가기</h2>
# <ul>
# <li><a href="#search"><strong>통합검색 바로가기</strong></a></li>
# <li><a href="#UI"><strong>로그인영역 바로가기</strong></a></li>
# <li><a href="#news_area"><strong>본문영역 바로가기</strong></a></li>
# </ul>
# </div>
# <div id="container">
# <div id="header">
# <div class="area_bi" id="NateBi" role="banner">
# <h1 class="bi" title="네이트"><a href="//www.nate.com/?f=bi" onmousedown="nc('NBI01');">네이트</a></h1>
# </div>
# <div class="area_ignb" id="divignb">
# <h2>독립GNB</h2>
# <h3>편리한 네이트</h3>
# <ul>
# <li><a href="https://search.daum.net/nate?thr=sbma&amp;w=tot&amp;q=%EB%84%A4%EC%9D%B4%ED%8A%B8%EC%95%B1" onmousedown="nc('NBI04');">네이트앱</a></li>
# <li><a href="//nateonweb.nate.com/" onmousedown="nc('NBI05');">네이트온</a></li>
# <li><a href="http://www.cymera.com/main/ko" onmousedown="nc('NBI07');">싸이메라</a></li>
# </ul>
# </div>
# <div class="area_search" role="search">
# <h2>통합검색</h2>
# <form accept-charset="utf-8" action="https://search.daum.net/nate" id="search" name="search" onsubmit="return checkSearchForm()">
# <input id="thr" name="thr" type="hidden" value="sbma"/>
# <input id="w" name="w" type="hidden" value="tot"/>
# <fieldset>
# <legend>통합검색 입력</legend>
# <div class="home" id="acWrap" onmouseover="ac_LoadByNateMain();">
# <input autocomplete="off" class="type_text" id="q" name="q" onkeydown="return checkSearchQEnter(event)" onmousedown="clickSearchKeywordAd()" style="ime-mode:active" type="text" value=""/>
# <input class="type_btn" id="acBtn" title="검색" type="submit"/>
# <div id="acDiv" style="display:none;"></div>
# </div>
# </fieldset>
# </form>
# <input id="premiumText" name="premiumText" title="" type="hidden" value="">
# <input id="premiumLink" name="premiumLink" title="" type="hidden" value=""/>
# <input id="statCode" name="statCode" title="" type="hidden" value=""/>
# <div class="search_keyword">
# <dl>
# <dd>
# <a href="https://search.daum.net/nate?w=tot&amp;q=음주+뺑소니+김호중&amp;rtmaxcoll=DNS" id="onclick_semantic01" onmousedown="setNcCode('NSC11|NSC21|NSC31',iSvcSeq-1);">음주 뺑소니 김호중</a>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%EC%9A%B8%EB%A6%89%EB%8F%84%EC%97%AC%ED%96%89" id="onclick_semantic02" onmousedown="setNcCode('NSC12|NSC22|NSC32',iSvcSeq-1);">울릉도여행</a>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%ED%98%84%EC%88%98%EB%A7%89%EC%A0%9C%EC%9E%91" id="onclick_semantic03" onmousedown="setNcCode('NSC13|NSC23|NSC33',iSvcSeq-1);">현수막제작</a>
# <a href="https://search.daum.net/nate?w=tot&amp;q=김종국+논현동+62억&amp;rtmaxcoll=DNS" id="onclick_semantic04" onmousedown="setNcCode('NSC14|NSC24|NSC34',iSvcSeq-1);">김종국 논현동 62억</a>
# <a href="https://search.daum.net/nate?w=tot&amp;q=한덕수+대선+출마&amp;rtmaxcoll=DNS" id="onclick_semantic05" onmousedown="setNcCode('NSC15|NSC25|NSC35',iSvcSeq-1);">한덕수 대선 출마</a>
# </dd>
# </dl>
# </div>
# <a class="link-ngpt" href="https://m.nate.com/aichat.html" onmousedown="nc('NNC01');" target="_blank">AI챗 바로가기</a>
# </input></div>
# <div class="area_gnb" id="divGnb" role="navigation">
# <h2>GNB</h2>
# <ul>
# <li class="mail"><a href="https://mail3.nate.com/#index" onmousedown="nc('NGB01');">메일</a></li>
# <li class="news"><a href="//news.nate.com/" onmousedown="nc('NEV31');">뉴스</a></li>
# <li class="pann"><a href="https://pann.nate.com/" onmousedown="nc('NGB02');">판</a></li>
# <li class="chat1"><a href="https://m.nate.com/aichat.html" onmousedown="nc('NGB51');" target="_blank">AI챗</a><em class="beta">beta</em></li>
# <li class="tv"><a href="https://tv.nate.com/" onmousedown="nc('NGB43');">TV</a></li>
# <li class="comics"><a href="https://toonnbook.nate.com/" onmousedown="nc('NGB44');">만화</a></li>
# <li class="fortune"><a href="https://fortune.nate.com/home/main.nate" onmousedown="nc('NGB05');">운세</a></li>
# <li class="game"><a href="http://game.nate.com/" onmousedown="nc('NGB06');">게임</a></li>
# <li class="shopping"><a href="//shopping.nate.com/" onmousedown="nc('NGB17');">쇼핑</a></li>
# <li class="teamroom"><a href="https://nateonweb.nate.com/teamroom/" onmousedown="nc('NGB42');" title="함께하는 일이 쉬워진다">팀룸</a></li>
# <li class=""><a href="https://view.nate.com/" onmousedown="nc('NGB50');" title="네이트뷰">네이트뷰</a></li>
# <li class=""><a href="https://cartech.nate.com/" onmousedown="nc('NGB03');" title="자동차">자동차</a></li>
# <li class="more">
# <a href="javascript:;" id="aGnbMore" onmousedown="nc('NGB31');" title="전체 서비스 더보기">더보기</a>
# <div class="list_svc" style="display:none">
# <ul class="row_first">
# <li><a href="//news.nate.com" onmousedown="nc('NSD30');"><strong>뉴스</strong></a></li>
# <li><a href="//news.nate.com/Weather" onmousedown="nc('NSD45');">날씨</a></li>
# <li><a href="//sports.news.nate.com/" onmousedown="nc('NSD74');">스포츠</a></li>
# <li><a href="//news.nate.com/ent/index" onmousedown="nc('NSD75');">연예</a></li>
# <li><a href="//news.nate.com/ent/idol24" onmousedown="nc('NSD02');">아이돌24</a></li>
# <li><a href="//news.nate.com/rank/interest" onmousedown="nc('NSD01');">랭킹뉴스</a></li>
# </ul>
# <ul class="row_second">
# <li><a href="https://pann.nate.com/" onmousedown="nc('NSD68');"><strong>판</strong></a></li>
# <li><a href="https://pann.nate.com/talk" onmousedown="nc('NSD06');">톡톡</a></li>
# <li><a href="https://pann.nate.com/fantalk" onmousedown="nc('NSD76');">팬톡</a></li>
# <li><a href="https://m.pann.nate.com/ptalk/" onmousedown="nc('NSD44');">펑톡</a></li>
# </ul>
# <ul class="row_third">
# <li><a href="//nateonweb.nate.com/" onmousedown="nc('NSD37');">네이트온</a></li>
# <li><a href="//cash.nate.com/center/cashMain.sc" onmousedown="nc('NSD38');">네이트캐쉬</a></li>
# <li><a href="https://sms.nate.com/" onmousedown="nc('NSD35');">문자메시지</a></li>
# <li><a href="https://mail.nate.com/pims/" onmousedown="nc('NSD34');">주소록</a></li>
# </ul>
# <ul class="row_fourth">
# <li><a href="//mobile.nate.com/" onmousedown="nc('NSD41');">컬러링</a></li>
# <li><a href="//m.ssul.nate.com/" onmousedown="nc('NSD46');">썰</a></li>
# </ul>
# <span><a href="https://www.nate.com/sitemap/index.html" onmousedown="nc('NSD91');">서비스 전체보기</a></span>
# <button onmousedown="nc('NSD95');" title="더보기 닫기" type="button" value="더보기 닫기">더보기 닫기</button>
# </div>
# </li>
# </ul>
# </div>
# <div class="area_rtkwd type_alone" id="keywordRank">
# <h3 class="nHide"><a href="#" title="네이트 인기검색어로 이동">실시간 검색어</a></h3>
# </div>
# <div class="area_biz type_alone" id="bizRank">
# <h3 class="nHide"><a href="#" title="네이트 인기검색어로 이동">비즈 검색어</a></h3>
# </div>
# <div class="nHide" id="divWhyArea"></div>
# </div>
# <hr/>
# <div id="content">
# <div class="area_auth" id="UI">
# <h2>회원 로그인 영역</h2>
# <script type="text/javascript">
#                     //<![CDATA[
#                         document.write('<script type="text/javascript" src="/common/secure/js/combine/combine_xecure_nate-secure_common.js?v=2022111801"><\/script>');
#                     //]]>
#                     </script>
# <form action="https://xo.nate.com/LoginAuth.sk" id="f_login" method="post" name="f_login" onsubmit="return SubmitCheck();" target="_top">
# <input id="redirect" name="redirect" type="hidden" value="https://www.nate.com/"/>
# <input id="PASSWD_RSA" name="PASSWD_RSA" type="hidden" value=""/>
# <input id="domain" name="domain" type="hidden" value="nate.com"/>
# <input name="cpurl" type="hidden" value="www_ndr.nate.com%2Flogin%2F"/>
# <fieldset>
# <legend>회원 로그인</legend>
# <label class="label_id nHide" for="ID">아이디 or @이하 모두 입력</label>
# <input class="input_id" id="ID" name="ID" style="ime-mode:disabled;" title="아이디 or @이하 모두 입력" type="text" value=""/>
# <label class="label_pw nHide" for="PASSDM">비밀번호</label>
# <label class="label_pw nHide" for="PASSDM" id="lb_passdm">비밀번호</label>
# <input class="input_pw" id="PASSDM" maxlength="20" name="PASSDM" readonly="readonly" type="text" value="비밀번호"/>
# <label class="label_pw nHide" for="PASSWD" id="lb_passwd">비밀번호</label>
# <input class="input_pw" enc="on" id="PASSWD" maxlength="20" name="PASSWD" onblur="vBlurPassInput();" style="display:none;ime-mode:disabled;" type="password"/>
# <span class="option01"><input class="chk_saveid" id="keeplogin" name="keeplogin" onclick="isKeepLogin('on')" onmousedown="nc('NCM94');" type="checkbox"/> <label class="set_saveid" for="keeplogin" onmousedown="nc('NCM94');">로그인 유지</label> <i class="bar">|</i> <a class="ip" href="javascript:xXecurePop.openWin(3);" onmousedown="nc('NLI15');" title="새창 열림">IP보안 <strong id="ipLevelText">ON</strong></a></span>
# <input class="icon_login" id="btnLOGIN" name="btnLOGIN" onkeydown="vkeydownSubmit(event);" type="submit" value="로그인"/>
# <span class="option02"><a href="javascript:onclick_Find();" title="아이디 찾기">아이디</a> / <a href="javascript:onclick_FindPW();" title="비밀번호 찾기">비밀번호 찾기</a> <i class="bar">|</i> <a href="javascript:onclick_Join();" title="회원가입"><strong>회원가입</strong></a> </span>
# <script type="text/javascript">
#                                 //<![CDATA[
#                                     initLogin();
#                                     nateLogin = new NateLogin('f_login', 'btnLOGIN', 'xo.nate.com/servlets/EncLoginServlet', loginBoxName, '비밀번호');
#                                 //]]>
#                                 </script>
# </fieldset>
# </form>
# <div class="overlay_info type_security" id="layerXKDisabled" style="display: none">
# <div class="layer_content"></div>
# </div>
# <div class="overlay_info nHide" id="divNateOn">
# <p>웹 네이트온 로그인은 설치가 필요 없는<br/>가벼운 네이트온이 네이트 로그인 만으로<br/>함께 로그인 되는 편리한 기능입니다.</p>
# <a href="//nateonweb.nate.com/nateon/download_web.php" onmousedown="nc('NLI75')" title="웹 네이트온이란?">웹 네이트온이란?</a>
# <button class="close" onclick="closeWebNateOnInfo()" title="알림 레이어 닫기" type="button" value="알림 레이어 닫기">알림 레이어 닫기</button>
# </div>
# <div class="overlay_info type_saveid nHide">
# <p>개인정보 보호를 위해<br/>개인PC에서만<br/>사용해 주세요. <a href="https://helpdesk.nate.com/web/faq-detail?faqId=KNOW0000000038&amp;subNodeId=NODE0000000006&amp;keyword=%EB%A1%9C%EA%B7%B8%EC%9D%B8%EC%9C%A0%EC%A7%80&amp;pageNo=1" onmousedown="nc('NLI33');" target="_blank" title="도움말보기">도움말보기 <i class="icon_arrow_right_red"></i></a></p>
# <button class="icon_x_black" onclick="closeKeepLoginLayer()" onmousedown="nc('NLI32');" title="알림 레이어 닫기" type="button" value="알림 레이어 닫기">알림 레이어 닫기</button>
# </div>
# </div>
# <hr/>
# <h2>컨텐츠 영역</h2>
# <div class="area_news" id="news_area">
# <h3>뉴스</h3>
# <div class="menu" id="newsTabMenu">
# <h4 class="menu01 on" id="newstab1"><a href="//news.nate.com/" onclick="newsBox.clickTabLink('tab1_set1');return false;" title="뉴스탭 열기">뉴스</a></h4>
# <h4 class="menu02" id="newstab2"><a href="//sports.news.nate.com/" onclick="newsBox.clickTabLink('tab2_spo');return false;" title="스포츠탭 열기">스포츠</a></h4>
# <h4 class="menu03" id="newstab3"><a href="//news.nate.com/ent/section?mid=e0100;" onclick="newsBox.clickTabLink('tab3_ent');return false;" title="연예탭 열기">연예</a></h4>
# <h4 class="menu04" id="newstab4" style="display:none;"></h4>
# <h4 class="menu05" id="newstab5"><a href="//news.nate.com/rank/?mid=n1000" onclick="newsBox.clickTabLink('tab5_ranking');return false;" title="랭킹뉴스탭 열기">랭킹뉴스</a></h4>
# </div>
# <div class="content type_news" id="newsContType" onfocusin="newsBox.rollingStop();" onfocusout="newsBox.rollingStart();">
# <div class="tabCnt">
# <div class="rankBox" id="div_rank_sisa"></div>
# <div class="rankBox" id="div_rank_spo"></div>
# <div class="rankBox" id="div_rank_ent"></div>
# <ul class="type_thumb type02" id="newsImg_ul_1">
# <li id="newsImg0">
# <a href="//news.nate.com/view/20250502n12161" onclick="setTabInfo();ndrclick('MEF09', 'NH_02_01_01-20250502113613');" target="_self">
# <em class="icon play">동영상</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2025/05/02/1746153369_389.jpg" width="168"/></span>
# <span class="txt">MLB서 '관중 추락' 사고…선수들도 충격</span>
# </a>
# </li>
# <li id="newsImg1">
# <a href="//ps.news.nate.com/photo/slideShow?cid=1113705" onclick="setTabInfo();ndrclick('MEF10', 'NH_01_01_01-20250502114806');" target="_self">
# <em class="icon slide">슬라이드</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2025/05/02/1746154025_292.png" width="168"/></span>
# <span class="txt">이재명 "여러분이 세상의 주인"…파기환송에 현장 행보로 돌파구</span>
# </a>
# </li>
# <li id="newsImg2">
# <a href="//ps.news.nate.com/photo/slideShow?cid=1113681&amp;mid=e0102" onclick="setTabInfo();ndrclick('MEF11', 'NH_03_01_02-20250502114611');" target="_self">
# <em class="icon slide">슬라이드</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2025/05/02/1746148156_301.jpg" width="168"/></span>
# <span class="txt">'승리·허웅 열애설♥' 유혜원, 쌍꺼풀 수술+입술 필러 고백 "네 찝었어요…맞았다 녹였다 아주 난리"</span>
# </a>
# </li>
# </ul>
# <ul class="type_text" id="newsTxt_ul_1">
# <li id="newsTxt_li_0"><strong><a href="//news.nate.com/hissue/clstList?mid=n0208&amp;isq=11000&amp;n=1113623#cid1113623" onclick="setTabInfo();ndrclick('MEB55', 'NH_01_02_04-20250502114516');" target="_self">李대행, 첫국무회의 주재…"국무위원 모두 권한대행이란 자세로"</a></strong></li>
# <li id="newsTxt_li_1"><a href="//news.nate.com/hissue/clstList?mid=n0412&amp;isq=11001&amp;n=1042774#cid1042774" onclick="setTabInfo();ndrclick('MEB57', 'NH_01_02_07-20250502125058');" target="_self">이재명 무죄 깨진 이유는 '유권자 관점'…표현자유보다 우선시</a></li>
# <li id="newsTxt_li_2"><a href="//news.nate.com/hissue/clstList?mid=n0412&amp;isq=11001&amp;n=975998#cid975998" onclick="setTabInfo();ndrclick('MEB59', 'NH_01_02_11-20250502103512');" target="_self">'입시비리' 2심 벌금형 조민, 판결 확정…검찰도 상고 안 해</a></li>
# <li id="newsTxt_li_3"><a href="//sports.news.nate.com/hissue/clstList?mid=s0106&amp;isq=8588&amp;n=763425#cid763425" onclick="setTabInfo();ndrclick('MEB61', 'NH_02_02_01-20250502124852');" target="_self">김경문 믿음의 결실…한화는 1할타자 2명이 연이틀 결승 홈런을 친다</a></li>
# <li id="newsTxt_li_4"><a href="//news.nate.com/hissue/clstList?mid=e0100&amp;isq=7377&amp;n=1113708#cid1113708" onclick="setTabInfo();ndrclick('MEC71', 'NH_03_02_04-20250502121048');" target="_self">"최초 부녀 출연' 임세미, '속옷 차림' 여공들에 "무서웠을 것" 눈물 (꼬꼬무)</a></li>
# </ul>
# <ul class="type_text" id="newsTxt_ul_2">
# <li id="newsTxt_li_5"><a href="//news.nate.com/view/20250502n10722" onclick="setTabInfo();ndrclick('MEF22', 'NH_01_02_12-20250502103817');" target="_self">15,000,000,000,000원…지방시장 침체에 대형건설사 미수금 급증</a></li>
# <li id="newsTxt_li_6"><strong><a href="//news.nate.com/hissue/clstList?mid=n0412&amp;isq=11001&amp;n=1105730#cid1105730" onclick="setTabInfo();ndrclick('MEF24', 'NH_01_02_08-20250502112505');" target="_self">박성재 법무부장관 조사했던 검사, 돌연 사의 표명</a></strong></li>
# <li id="newsTxt_li_7"><a href="//sports.news.nate.com/hissue/groupList?mid=s0606&amp;isq=10567&amp;sisq=10388" onclick="setTabInfo();ndrclick('MEF26', 'NH_02_02_02-20250502120635');" target="_self">'노안 윙어' 로번을 아시나요? '고향 유소년팀' 감독 됐다</a></li>
# <li id="newsTxt_li_8"><a href="//sports.news.nate.com/hissue/groupList?mid=s0606&amp;isq=10567&amp;sisq=10393" onclick="setTabInfo();ndrclick('MEF28', 'NH_02_02_01-20250502121406');" target="_self">"-6까지 갔었는데…" 명장도 내심 놀란 한화 대반전, 4월을 +6으로 끝내다니. 1992년 빙그레 시절 이후 '최고의 봄'</a></li>
# <li id="newsTxt_li_9"><a href="//news.nate.com/ent/subsection?mid=e1200&amp;n=1113703#cid1113703" onclick="setTabInfo();ndrclick('MEF30', 'NH_03_02_04-20250502113209');" target="_self">박명수, 지각해 놓고 "날씨 좋다"는 메인 작가에 "일찍 다니길" 일침</a></li>
# </ul>
# <ul class="type_text" id="newsTxt_ul_3">
# <li id="newsTxt_li_10"><a href="//news.nate.com/view/20250502n11168" onclick="setTabInfo();ndrclick('MEB63', 'NH_01_02_13-20250502103953');" target="_self">한덕수 출마 만류했다는 황교안 "이 나라 어찌할꼬" 썼다가 삭제</a></li>
# <li id="newsTxt_li_11"><strong><a href="//news.nate.com/hissue/clstList?mid=n0208&amp;isq=10081&amp;n=1024911#cid1024911" onclick="setTabInfo();ndrclick('MEB65', 'NH_01_02_09-20250502125546');" target="_self">"북한 용덕동 핵시설 가동중…폭발구와 유사한 구덩이도 포착"</a></strong></li>
# <li id="newsTxt_li_12"><a href="//news.nate.com/hissue/clstList?mid=n0309&amp;isq=10477&amp;n=838426#cid838426" onclick="setTabInfo();ndrclick('MEB67', 'NH_01_02_15-20250502120138');" target="_self">무섭게 느는 월세…서울 월세물가, 11년 만에 최대폭 증가</a></li>
# <li id="newsTxt_li_13"><a href="//sports.news.nate.com/hissue/clstList?mid=s0406&amp;isq=8655&amp;n=1031804#cid1031804" onclick="setTabInfo();ndrclick('MEB69', 'NH_02_02_03-20250502063818');" target="_self">이강인(24·페네르바체) 충격 이적 터진다! 무리뉴 러브콜…"슈퍼스타로 만들고 싶어해", "김민재도 설득 나선다" (프랑스 매체)</a></li>
# <li id="newsTxt_li_14"><a href="//news.nate.com/ent/subsection?mid=e1200&amp;n=1113679#cid1113679" onclick="setTabInfo();ndrclick('MEC73', 'NH_03_02_07-20250502114602');" target="_self">"식스센스급 반전" 동생 뺨 때리는 금쪽이, 母 오기 전 입단속까지</a></li>
# </ul>
# <ul class="type_thumb type01 nHide" id="newsImg_ul_2">
# <li id="newsImg3"></li>
# <li id="newsImg4"></li>
# </ul>
# <div class="overlay_plus type01" id="newsPlusLayer" style="display:none">
# <div class="plus_content">
# <iframe frameborder="0" height="470" id="newsIfr" scrolling="no" src="about:blank" title="뉴스플러스 아이프레임" width="304"></iframe>
# <button class="close" onclick="closeNewsPlus();ndrclick('MEC49','');" title="뉴스플러스 레이어 닫기" type="button" value="뉴스플러스 레이어 닫기">뉴스플러스 레이어 닫기</button>
# </div>
# </div>
# </div>
# <div class="bizCnt">
# <div class="weatherBox">
# <div class="title">오늘의 날씨</div>
# <div class="todayBox" id="todayBoxWeather">
# <h3><strong class="tdate">05.02</strong> 금요일</h3>
# <a class="tempinfo" href="http://news.nate.com/Weather?areaCode=11B10101" onmousedown="nc('MEH10');">
# <div>
# <div class="misc">
# <img alt="구름많음" height="42" src="//main2.nateimg.co.kr/img/v7/weather4/52x52_am_03.png" width="42"/>
# </div>
# <div class="temperature">
# <span class="tempdata">17</span>
# </div>
# <div class="rbox">
# <span class="degree">℃</span>
# <span class="local">서울</span>
# </div>
# </div>
# </a>
# <div class="plusinfo">
# <p class="rangeTemp">어제보다 <span>
#
#
#
# 								+3℃ 높음
#
#
#
# 					</span></p>
# <a href="http://news.nate.com/weather/airPollution?type=pm10" onmousedown="nc('MEH11');"><p class="dust">미세먼지 <span class="pol1">좋음</span></p></a>
# </div>
# </div>
# </div>
# <div class="adBox"></div>
# <div class="todayBox" id="divBox">
# <a class="cmBox2" href="https://m.ssul.nate.com/" target="_self">
# <span class="thumb"><img alt=" 네이트썰" height="138" onmousedown="nc('MEH16');" src="//main.nateimg.co.kr/img/cms/content_pool/2025/03/1742962359601.png" width="168"/></span>
# </a>
# </div>
# </div>
# <dl class="content_recommend">
# <dt id="dtNewsRecomm"><em>뉴스</em></dt>
# <dd id="newsRecommend">
# <a href="//news.nate.com/comment?mid=n1500" onmousedown="nc('MEF42');setTabInfo();">투데이베플</a>
# <a href="//news.nate.com/ent/idol24" onmousedown="nc('MEF43');setTabInfo();">아이돌24시</a>
# <a href="//news.nate.com/hissue/clstList?mid=e0103&amp;isq=7376" onmousedown="nc('MEF44');setTabInfo();">드라마 모아보기</a>
# <a href="//news.nate.com/hissue/clstList?mid=e0103&amp;isq=7377" onmousedown="nc('MEF45');setTabInfo();">예능 모아보기</a>
# </dd>
# </dl>
# </div>
# <div class="nav" id="newsOptBtn">
# <span id="newsMoreArea"><em>3</em> / 6</span>
# <button class="pause" id="newsRollingBtn" onclick="newsBox.changeRolling();" title="자동전환기능 정지" type="button" value="자동전환기능 정지">자동전환기능 정지</button>
# <button class="prev" onclick="ndrclick('MEC42');newsBox.showPreNext('P');" title="이전 뉴스 보기" type="button" value="이전 뉴스 보기">이전 뉴스 보기</button>
# <button class="next" onclick="ndrclick('MEC43');newsBox.showPreNext('N');" title="다음 뉴스 보기" type="button" value="다음 뉴스 보기">다음 뉴스 보기</button>
# </div>
# <div id="newsNotice"></div>
# <div class="overlay_ticker" id="ticker_lyr" style="display:none">
# <div class="ticker_content">
# <iframe frameborder="0" height="318" id="ticker_ifm" scrolling="no" src="about:blank" title="티커 아이프레임" width="728"></iframe>
# <button class="close" onclick="nateonTickerClose();" title="티커 닫기" type="button" value="티커 닫기">티커 닫기</button>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 					//<![CDATA[
# 					loadSpecialBiRolling();
# 					//]]>
# 				</script>
# <!-- tiles:insertAttribute name="NateQ" /-->
# <div class="area_contents" id="divContentsUpper">
# <h3>컨텐츠</h3>
# <div class="menu">
# <h4 class="menu01"><a href="//pann.nate.com/talk/ranking" onclick="objPannArea.clickTab(0);return false;" onmousedown="nc('PAN60')" title="Top랭킹">Top랭킹</a></h4>
# <h4 class="menu02"><a href="//pann.nate.com/talk/c20025" onclick="objPannArea.clickTab(1);return false;" onmousedown="nc('PAN61')" title="결시친">결시친</a></h4>
# <h4 class="menu03 on"><a href="//pann.nate.com/talk/c20038" onclick="objPannArea.clickTab(2);return false;" onmousedown="nc('PAN62')" title="10대톡">10대톡</a></h4>
# <h4 class="menu04"><a href="//pann.nate.com/talk/c20028" onclick="objPannArea.clickTab(3);return false;" onmousedown="nc('PAN63')" title="연예톡">연예톡</a></h4>
# <h4 class="menu05"><a href="//pann.nate.com/talk/c20019" onclick="objPannArea.clickTab(4);return false;" onmousedown="nc('PAN64')" title="회사톡">회사톡</a></h4>
# </div>
# <div class="content" id="pannList">
# <ul class="ctList">
# <!-- 썸네일 있는 경우 -->
# <li class="type_thumb">
# <a class="" href="https://pann.nate.com/talk/374308156" onmousedown="nc('PAO21');objPannArea.clickContents(3);">
# <span class="thumb"><img alt="" height="66" src="https://thumb.pann.com/tc_110x70/http://fimg6.pann.com/new/download.jsp?FileID=68764539" width="105"/></span>
# <span class="title">요즘 애들이름 너무 특징없어보이지 않아?</span>
# <em class="emph"><span class="nHide">댓글수</span>(187)</em>
# </a>
# </li>
# <!-- 썸네일 있는 경우 -->
# <li class="type_thumb">
# <a class="" href="https://pann.nate.com/talk/374306758" onmousedown="nc('PAO22');objPannArea.clickContents(3);">
# <span class="thumb"><img alt="" height="66" src="https://thumb.pann.com/tc_110x70/http://fimg6.pann.com/new/download.jsp?FileID=68763696" width="105"/></span>
# <span class="title">제주도 당근 진짜 이런사람 많아?</span>
# <em class="emph"><span class="nHide">댓글수</span>(60)</em>
# </a>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(41)</span>
# <a class="link" href="https://pann.nate.com/talk/374307009" onmousedown="nc('PAO23');objPannArea.clickContents(3);">김재중 여친 빡세네</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(50)</span>
# <a class="link" href="https://pann.nate.com/talk/374307172" onmousedown="nc('PAO24');objPannArea.clickContents(3);">근데 이사배 화장은</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(44)</span>
# <a class="link" href="https://pann.nate.com/talk/374306926" onmousedown="nc('PAO25');objPannArea.clickContents(3);">안꾸미면 ㄹㅇ이럼...?</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(26)</span>
# <a class="link" href="https://pann.nate.com/talk/374307011" onmousedown="nc('PAO26');objPannArea.clickContents(3);">성찬원빈 미쳤다</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(27)</span>
# <a class="link" href="https://pann.nate.com/talk/374308333" onmousedown="nc('PAO27');objPannArea.clickContents(3);">난 장카설보다 진심 얘가 제일 이쁨</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(15)</span>
# <a class="link" href="https://pann.nate.com/talk/374308055" onmousedown="nc('PAO28');objPannArea.clickContents(3);">찐따들은 성인돼도 티 못숨김</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(12)</span>
# <a class="link" href="https://pann.nate.com/talk/374307261" onmousedown="nc('PAO29');objPannArea.clickContents(3);">엔위시 재희는 이름 바꿔야됨</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(28)</span>
# <a class="link" href="https://pann.nate.com/talk/374307495" onmousedown="nc('PAO30');objPannArea.clickContents(3);">나 피부 하얀편인데 친구가</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(13)</span>
# <a class="link" href="https://pann.nate.com/talk/374307076" onmousedown="nc('PAO31');objPannArea.clickContents(3);">유퀴즈 나오는 저 문우진이라는 남자애</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(16)</span>
# <a class="link" href="https://pann.nate.com/talk/374306388" onmousedown="nc('PAO32');objPannArea.clickContents(3);">이정도로 예뻐지려면 성형이나시술 어떤거해야됨?</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(12)</span>
# <a class="link" href="https://pann.nate.com/talk/374307323" onmousedown="nc('PAO33');objPannArea.clickContents(3);">친구 집 갔다가 문화충격 받음</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(14)</span>
# <a class="link" href="https://pann.nate.com/talk/374308038" onmousedown="nc('PAO34');objPannArea.clickContents(3);">예쁜찐따는 찐따여도 인기많음?</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(9)</span>
# <a class="link" href="https://pann.nate.com/talk/374307973" onmousedown="nc('PAO35');objPannArea.clickContents(3);">돈없는애랑 여행 ㄹㅇ못가겟음</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(10)</span>
# <a class="link" href="https://pann.nate.com/talk/374306759" onmousedown="nc('PAO36');objPannArea.clickContents(3);">엔믹스 릴리 정도면 예쁜 편이냐?</a>
# </div>
# </li>
# </ul>
# </div>
# <!-- nav -->
# <div class="nav">
# <span id="pannNav"><a href="//pann.nate.com/" onmousedown="nc('PAN65')">판홈</a> <i>|</i> <em>3</em> / 5</span>
# <button class="prev" onclick="objPannArea.clickButton('P');" onmousedown="nc('PAN98')" title="이전 컨텐츠 보기" type="button" value="이전 컨텐츠 보기">이전 컨텐츠 보기</button>
# <button class="next" onclick="objPannArea.clickButton('N');" onmousedown="nc('PAN99')" title="다음 컨텐츠 보기" type="button" value="다음 컨텐츠 보기">다음 컨텐츠 보기</button>
# </div>
# <!-- //nav -->
# </div>
# <div class="area_issue" id="divIssueUp">
# <h3>키워드</h3>
# <div class="menu">
# <div class="keyword_list">
# <div class="list_top">
# <h4 class="menu01"><a href="javascript:issueContents.clickIssueUpNateTv(0)" onmousedown="nc('CTG08')">TV</a></h4>
# <h4 class="menu02"><a href="javascript:issueContents.clickIssueUpNateView('travel')" onmousedown="nc('CTG01');">여행/맛집</a></h4>
# <h4 class="menu03 on"><a href="javascript:issueContents.clickIssueUpNateView('fun')" onmousedown="nc('CTG10');">FUN</a></h4>
# <h4 class="menu04"><a href="javascript:issueContents.clickIssueUpToonNBook()" onmousedown="nc('CTG09');">만화/웹툰</a></h4>
# <h4 class="menu05"><a href="javascript:issueContents.clickIssueUpNateView('life')" onmousedown="nc('CTG06');">라이프</a></h4>
# <h4 class="menu06"><a href="javascript:issueContents.clickIssueUpNateView('car')" onmousedown="nc('CTG11')">자동차</a></h4>
# <h4 class="menu07" id="issueTabShopping"><a href="javascript:issueContents.clickIssueUpShopping()" onmousedown="nc('CTG07');">쇼핑</a></h4>
# </div>
# <div class="list_btm" id="divIssueKeyword">
# <span>세상의 모든 재미 '네이트뷰'에서 확인하세요!</span>
# </div>
# </div>
# </div>
# <div class="content" id="divIssueUpContents">
# <ul>
# <li>
# <a href="https://view.nate.com/fun/view/304312/" onmousedown="nc('CDA01');issueContents.setBackButtonCookie(2, 0);">
# <span class="thumb"><img height="126" src="https://contents-cdn.viewus.co.kr/thumbnail/2025/05/content-ad-70/thumb-304312-510x380.jpg" width="169"/></span>
# <span class="title">BBC 선정 건강한 음식 18위</span>
# </a>
# <cite>FUN</cite>
# </li>
# <li>
# <a href="https://view.nate.com/fun/view/304313/" onmousedown="nc('CDA02');issueContents.setBackButtonCookie(2, 0);">
# <span class="thumb"><img height="126" src="https://contents-cdn.viewus.co.kr/thumbnail/2025/05/content-ad-70/thumb-304313-510x380.jpg" width="169"/></span>
# <span class="title">운전면허따면 서울에서 꼭 가봐야 할곳</span>
# </a>
# <cite>FUN</cite>
# </li>
# <li>
# <a href="https://view.nate.com/fun/view/304314/" onmousedown="nc('CDA03');issueContents.setBackButtonCookie(2, 0);">
# <span class="thumb"><img height="126" src="https://contents-cdn.viewus.co.kr/thumbnail/2025/05/content-ad-70/thumb-304314-510x380.jpg" width="169"/></span>
# <span class="title">집사의 손침대가 맘에 든 고양이 (심장폭행주의..)</span>
# </a>
# <cite>FUN</cite>
# </li>
# <li>
# <a href="https://view.nate.com/fun/view/304311/" onmousedown="nc('CDA04');issueContents.setBackButtonCookie(2, 0);">
# <span class="thumb"><img height="126" src="https://contents-cdn.viewus.co.kr/thumbnail/2025/05/content-ad-70/thumb-304311-510x380.jpg" width="169"/></span>
# <span class="title">넷플 ＜올드가드 2＞ 퍼스트룩 공개</span>
# </a>
# <cite>FUN</cite>
# </li>
# <li>
# <a href="https://view.nate.com/fun/view/304301/" onmousedown="nc('CDA05');issueContents.setBackButtonCookie(2, 0);">
# <span class="thumb"><img height="126" src="https://contents-cdn.viewus.co.kr/thumbnail/2025/05/content-ad-70/thumb-304301-510x380.jpg" width="169"/></span>
# <span class="title">19세기 미국 노예들이 먹었다는 음식</span>
# </a>
# <cite>FUN</cite>
# </li>
# <li>
# <a href="https://view.nate.com/fun/view/304302/" onmousedown="nc('CDA06');issueContents.setBackButtonCookie(2, 0);">
# <span class="thumb"><img height="126" src="https://contents-cdn.viewus.co.kr/thumbnail/2025/05/content-ad-70/thumb-304302-510x380.jpg" width="169"/></span>
# <span class="title">솔직하신 할머니</span>
# </a>
# <cite>FUN</cite>
# </li>
# <li>
# <a href="https://view.nate.com/fun/view/304304/" onmousedown="nc('CDA07');issueContents.setBackButtonCookie(2, 0);">
# <span class="thumb"><img height="126" src="https://contents-cdn.viewus.co.kr/thumbnail/2025/05/content-ad-70/thumb-304304-510x380.jpg" width="169"/></span>
# <span class="title">조이 폼 돌아온듯?</span>
# </a>
# <cite>FUN</cite>
# </li>
# <li>
# <a href="https://view.nate.com/fun/view/304306/" onmousedown="nc('CDA08');issueContents.setBackButtonCookie(2, 0);">
# <span class="thumb"><img height="126" src="https://contents-cdn.viewus.co.kr/thumbnail/2025/05/content-ad-70/thumb-304306-510x380.jpg" width="169"/></span>
# <span class="title">공부 목적을 달성한 박명수 아내</span>
# </a>
# <cite>FUN</cite>
# </li>
# <li>
# <a href="https://view.nate.com/fun/view/304292/" onmousedown="nc('CDA09');issueContents.setBackButtonCookie(2, 0);">
# <span class="thumb"><img height="126" src="https://contents-cdn.viewus.co.kr/thumbnail/2025/05/content-ad-70/thumb-304292-510x380.jpg" width="169"/></span>
# <span class="title">다소 충격적인 미아역 흉기 사건 목격자 증언</span>
# </a>
# <cite>FUN</cite>
# </li>
# <li>
# <a href="https://view.nate.com/fun/view/304298/" onmousedown="nc('CDA10');issueContents.setBackButtonCookie(2, 0);">
# <span class="thumb"><img height="126" src="https://contents-cdn.viewus.co.kr/thumbnail/2025/05/content-ad-70/thumb-304298-510x380.jpg" width="169"/></span>
# <span class="title">교황 조문하는 명동성당에 뜬 무지개</span>
# </a>
# <cite>FUN</cite>
# </li>
# <li>
# <a href="https://view.nate.com/fun/view/304294/" onmousedown="nc('CDA11');issueContents.setBackButtonCookie(2, 0);">
# <span class="thumb"><img height="126" src="https://contents-cdn.viewus.co.kr/thumbnail/2025/05/content-ad-70/thumb-304294-510x380.jpg" width="169"/></span>
# <span class="title">육성재 흑역사</span>
# </a>
# <cite>FUN</cite>
# </li>
# <li>
# <a href="https://view.nate.com/fun/view/304290/" onmousedown="nc('CDA12');issueContents.setBackButtonCookie(2, 0);">
# <span class="thumb"><img height="126" src="https://contents-cdn.viewus.co.kr/thumbnail/2025/05/content-ad-70/thumb-304290-510x380.jpg" width="169"/></span>
# <span class="title">깊게 파고드는걸 원하지 않는 오덕들</span>
# </a>
# <cite>FUN</cite>
# </li>
# </ul>
# </div>
# <div class="content type_err nHide" id="emergencyLayer">
# <h4 class="">쇼핑탭 점검중</h4>
# <p>불편을 드려 죄송합니다.<br>더 좋은 서비스를 위해<br><strong>쇼핑탭은 지금 점검</strong> 중입니다.</br></br></p>
# <a href="https://shopping.nate.com/">네이트 쇼핑으로 바로가기</a>
# </div>
# <div class="overlay_ally" style="display:none;"></div>
# <div class="movplay" id="movieSec">
# <div class="issuemov">
# <div id="divPlayer"></div>
# <a class="btn_view_detail" href="" id="movieDetailLink" onmousedown="javascript:nc('MVA02');" target="" title="광고 자세히보기">광고 자세히보기</a>
# <button class="btn_x_small_white" onclick="issueContents.closeMovie();" onmousedown="nc('CZA02')" title="동영상 플레이 레이어 닫기" type="button" value="동영상 플레이 레이어 닫기">동영상 플레이 레이어 닫기</button>
# </div>
# <span class="shadow"></span>
# </div>
# <div class="content type_err tbe nHide" id="divToonNBookErrLayer">
# <h4 class="">만화/웹툰탭 점검중</h4>
# <p>불편을 드려 죄송합니다.<br/>더 좋은 서비스를 위해<br/><strong>만화/웹툰탭은 지금 점검</strong> 중입니다.</p>
# <a href="https://toonnbook.nate.com">네이트 만화로 바로가기</a>
# </div>
# <div class="content type_err tbe nHide" id="divIssueUpErrLayer">
# <h4 class="">FUN탭 점검중</h4>
# <p>불편을 드려 죄송합니다.<br/>더 좋은 서비스를 위해<br/><strong>FUN탭은 지금 점검</strong> 중입니다.</p>
# </div>
# </div>
# <div class="area_ranking">
# <h3>랭킹</h3>
# <div class="menu">
# <h4 class="menu04">Fun &amp; Fun 해</h4>
# </div>
# <div class="content" onmouseout="nateRanking.startRolling()" onmouseover="nateRanking.stopRolling()">
# <ul class="type_thumb">
# <li>
# <a href="https://fortune.nate.com/content/contentInfo.nate?searchcontscd=CT000463" onmousedown="nc('RKN91')" title="운세ㅣ그 사람이 원하는 것은?"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2025/04/1745912564498.gif"/></span>
# <span class="title">운세ㅣ그 사람이 원하는 것은?<span class="cite">그 사람의 7가지 본심</span></span></a>
# </li>
# <li>
# <a href="https://fortune.nate.com/event/mentoring/default.nate" onmousedown="nc('RKN92')" title="운세ㅣ타로카드로 보는"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2025/04/1745912577139.gif"/></span>
# <span class="title">운세ㅣ타로카드로 보는<span class="cite">5월 2일 오늘의 운세</span></span></a>
# </li>
# <li>
# <a href="http://ex.nate.pupugame.com/" onmousedown="nc('RKN93')" title="엘카인 l 당신이 기다렸던"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2025/04/1745903198947.jpg"/></span>
# <span class="title">엘카인 l 당신이 기다렸던<span class="cite">만능 판타지 RPG의 시작!</span></span></a>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H013101310" onmousedown="nc('RKN94')" title="만화 | 운명처럼 나타난 절대무인"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2025/04/1745559428248.png"/></span>
# <span class="title">만화 | 운명처럼 나타난 절대무인<span class="cite">악삼황</span></span></a>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H047603097" onmousedown="nc('RKN95')" title="웹툰 | 과연 헤어질 수 있을까?"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2025/04/1745559642954.png"/></span>
# <span class="title">웹툰 | 과연 헤어질 수 있을까?<span class="cite">악녀의 남주님</span></span></a>
# </li>
# </ul>
# </div>
# <div class="paging_slide">
# <span class="num_count_1"><em>1</em> / 2</span>
# <button class="btn prev" onclick="nateRanking.clickRankingBtn('P');" onmousedown="nc('RKN98');" title="이전" type="button">이전</button>
# <button class="btn next" onclick="nateRanking.clickRankingBtn('N');" onmousedown="nc('RKN99');" title="다음" type="button">다음</button>
# </div>
# </div>
# <hr/>
# <h2>쇼핑&amp; 광고 영역</h2>
# <div class="area_shopping" id="shopping" style="display:none">
# <h3>쇼핑</h3>
# <div class="mall1shop" id="shopitemMall">
# <h3 class="tab" id="mall1Title"><a class="link" href="http://shopping.nate.com" onmousedown="ndrclick2('NFA01')" target="_top">쇼핑홈</a></h3>
# <div class="shopmall" id="mall1Box"></div>
# <h3 class="tab" id="mall2Title"><a class="link" href="#" onmousedown="ndrclick2('NFC01')" target="_blank"></a></h3>
# <div class="shopmall nHide" id="mall2Box"></div>
# <h3 class="tab" id="mall3Title"><a class="link" href="#" onmousedown="ndrclick2('NFE01')" target="_blank"></a></h3>
# <div class="shopmall nHide" id="mall3Box"></div>
# <h3 class="tab" id="mall4Title"><a class="link" href="#" onmousedown="ndrclick2('NFG01')" target="_blank"></a></h3>
# <div class="shopmall nHide" id="mall4Box"></div>
# <div id="relShopping">
# <strong class="nHide">쇼핑 관련 리스트</strong>
# <div class="paging_slide">
# <button class="btn prev" id="shoppingPrev" onmousedown="ndrclick2('NFZ01')" title="이전" type="button">쇼핑 이전 내용</button>
# <button class="btn next" id="shoppingNext" onmousedown="ndrclick2('NFZ02')" title="다음" type="button">쇼핑 다음 내용</button>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# //<![CDATA[
#     var nDt = new Date();
#     var verShop = '' + (nDt.getMonth()+1) + nDt.getDate() + nDt.getHours() + nDt.getMinutes();
# //]]>
# </script>
# </div>
# <div class="area_shopping type_err" id="shopping_err" style="display:none">
# <h4 class="">쇼핑박스 점검중</h4>
# <p>불편을 드려 죄송합니다.<br/>더 좋은 서비스를 위해<br/><strong>쇼핑박스는 지금 점검</strong> 중입니다.</p>
# <a href="http://shopping.nate.com">네이트 쇼핑으로 바로가기</a>
# </div>
# <div class="area_shopping_today">
# <!-- tiles:insertAttribute name="shopRecommendation" /-->
# </div>
# <!-- 하단 숏폼 -->
# <div class="short-form-content" id="divShortForm">
# <div class="title"><a href="https://shortform.nate.com/best" onclick="nc('RCM10');">짧고 강한 재미! 🎬 오늘의 숏폼</a></div>
# <div class="best-shortform-wrap">
# <ul class="best-shortform">
# <li>
# <a href="https://shortform.nate.com/best?videoId=0L8RxP_BXz0" onclick="nc('RCM11');" target="_blank">
# <div class="thumb">
# <img onerror="this.onerror=null; this.src='//main.nateimg.co.kr/img/v7/img_error_thumb.png'" src="https://thumbshort.nateimg.co.kr/unsafe/187x1:452x476/267x475/https://i.ytimg.com/vi/0L8RxP_BXz0/sddefault.jpg">
# </img></div>
# <div class="subject">주작 논란 후 파뿌리 근황</div>
# </a>
# </li>
# <li>
# <a href="https://shortform.nate.com/best?videoId=q_7MfhnwLQU" onclick="nc('RCM12');" target="_blank">
# <div class="thumb">
# <img onerror="this.onerror=null; this.src='//main.nateimg.co.kr/img/v7/img_error_thumb.png'" src="https://thumbshort.nateimg.co.kr/unsafe/187x1:452x476/267x475/https://i.ytimg.com/vi/q_7MfhnwLQU/sddefault.jpg">
# </img></div>
# <div class="subject">사람마다 갈리는 삼겹살 취향</div>
# </a>
# </li>
# <li>
# <a href="https://shortform.nate.com/best?videoId=MKKSLEcGWR0" onclick="nc('RCM13');" target="_blank">
# <div class="thumb">
# <img onerror="this.onerror=null; this.src='//main.nateimg.co.kr/img/v7/img_error_thumb.png'" src="https://thumbshort.nateimg.co.kr/unsafe/187x1:452x476/267x475/https://i.ytimg.com/vi/MKKSLEcGWR0/sddefault.jpg">
# </img></div>
# <div class="subject">인사성 바른 카리나 어린이</div>
# </a>
# </li>
# <li>
# <a href="https://shortform.nate.com/best?videoId=udU-RqL-Auc" onclick="nc('RCM14');" target="_blank">
# <div class="thumb">
# <img onerror="this.onerror=null; this.src='//main.nateimg.co.kr/img/v7/img_error_thumb.png'" src="https://thumbshort.nateimg.co.kr/unsafe/187x1:452x476/267x475/https://i.ytimg.com/vi/udU-RqL-Auc/sddefault.jpg">
# </img></div>
# <div class="subject">[엔믹스] 넘어진 유진님과 엔믹스 멤버들의 반응 ㅋㅋㅋㅋ</div>
# </a>
# </li>
# <li>
# <a href="https://shortform.nate.com/best?videoId=1u4HSlfC4y0" onclick="nc('RCM15');" target="_blank">
# <div class="thumb">
# <img onerror="this.onerror=null; this.src='//main.nateimg.co.kr/img/v7/img_error_thumb.png'" src="https://thumbshort.nateimg.co.kr/unsafe/187x1:452x476/267x475/https://i.ytimg.com/vi/1u4HSlfC4y0/sddefault.jpg">
# </img></div>
# <div class="subject">(중요)SKT안써도 당장 막으세요(해킹대처법)</div>
# </a>
# </li>
# <li>
# <a href="https://shortform.nate.com/best?videoId=Y9jgQsaW8Jk" onclick="nc('RCM16');" target="_blank">
# <div class="thumb">
# <img onerror="this.onerror=null; this.src='//main.nateimg.co.kr/img/v7/img_error_thumb.png'" src="https://thumbshort.nateimg.co.kr/unsafe/187x1:452x476/267x475/https://i.ytimg.com/vi/Y9jgQsaW8Jk/sddefault.jpg"/>
# </div>
# <div class="subject">너구리 라면의 소름돋는 진실</div>
# </a>
# </li>
# <li>
# <a href="https://shortform.nate.com/best?videoId=Q2pfLzJvShI" onclick="nc('RCM17');" target="_blank">
# <div class="thumb">
# <img onerror="this.onerror=null; this.src='//main.nateimg.co.kr/img/v7/img_error_thumb.png'" src="https://thumbshort.nateimg.co.kr/unsafe/187x1:452x476/267x475/https://i.ytimg.com/vi/Q2pfLzJvShI/sddefault.jpg"/>
# </div>
# <div class="subject">진짜 공주가 있다? 세대별 '확신의 공주상' 아이돌 총정리 [영상]</div>
# </a>
# </li>
# <li>
# <a href="https://shortform.nate.com/best?videoId=i30e7gtE5hk" onclick="nc('RCM18');" target="_blank">
# <div class="thumb">
# <img onerror="this.onerror=null; this.src='//main.nateimg.co.kr/img/v7/img_error_thumb.png'" src="https://thumbshort.nateimg.co.kr/unsafe/187x1:452x476/267x475/https://i.ytimg.com/vi/i30e7gtE5hk/sddefault.jpg"/>
# </div>
# <div class="subject">#2787. CCTV에 찍힌 사고 순간! #shorts #automobile #주행 #뉴스 #카닥</div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <!-- //하단 숏폼 -->
# <div class="ad_area_bottom">
# <div class="area_ad09"></div>
# <div class="area_ad10">
# <a href="https://nateonweb.nate.com/" onmousedown="setNcCode('NAA21|NAA22',iSvcSeqC-1);"><img alt=" 네이트온" height="90" src="//main.nateimg.co.kr/img/cms/content_pool/2025/01/1735781333132.png" width="332"/></a>
# </div>
# </div>
# <div class="area_quick" id="divQuickMenu">
# <h3>퀵링크</h3>
# <div class="area_sktad01"></div>
# <ul>
# <li class="totop"><a href="javascript:;" onmousedown="nc('RAB15');"><span>맨위로</span></a></li>
# <li>
# <a href="https://tv.nate.com/" onmousedown="nc('RAB25');" title="네이트TV 서비스 가기">네이트TV</a>
# </li>
# <li>
# <a href="https://m.ssul.nate.com/" onmousedown="nc('RAB26');" title="네이트썰 서비스 가기">네이트썰</a>
# </li>
# <li>
# <a href="https://mobile.nate.com/decorate/mvno/top" onmousedown="nc('RAB19');" title="컬러링 서비스 가기">컬러링</a>
# </li>
# <li>
# <a href="https://view.nate.com/" onmousedown="nc('RAB27');" title="네이트뷰 서비스 가기">네이트뷰</a>
# </li>
# <li class="issue"><a href="javascript:;" onmousedown="nc('RAB08');">이슈<em class="issueup">UP</em></a></li>
# </ul>
# </div>
# <div class="area_mallAd" id="divMallMenu"></div>
# </div>
# <hr/>
# <div id="footer">
# <h2>푸터 영역</h2>
# <div class="notice">
# <h3><a href="https://helpdesk.nate.com/web/notice/main" onmousedown="nc('NFT01');">공지사항</a></h3>
# <a href="https://helpdesk.nate.com/web/notice/main-detail?id=8868" onmousedown="nc('NFT02');">네이트 개인정보 처리방침 개정 사전 안내</a>
# </div>
# <dl>
# <dt>네이트 공용 푸터</dt>
# <dd>
# <a href="http://www.skcomms.co.kr/" onmousedown="nc('NFT21');">회사소개</a> <span>|</span>
# <a href="http://business.nate.com/" onmousedown="nc('NFT29');">광고문의</a> <span>|</span>
# <a href="/policy/legal.html" onmousedown="nc('NFT24');">서비스 약관</a> <span>|</span>
# <a href="/policy/privacy.html" onmousedown="nc('NFT25');"><strong>개인정보처리방침</strong></a> <span>|</span>
# <a href="/policy/youthpolicy.html" onmousedown="nc('NFT26');">청소년보호정책</a> <span>|</span>
# <a href="http://helpdesk.nate.com/" onmousedown="nc('NFT11');">고객센터</a> <span>|</span>
# <span class="copyright">© <a href="https://www.natecorp.com" onmousedown="nc('NFT41');" target="_blank"><strong>NATE Communications</strong></a></span>
# </dd>
# </dl>
# <a class="view_all" href="/sitemap/index.html" onmousedown="nc('NFT12');">서비스 전체보기</a>
# </div>
# <hr/>
# <div id="adContainer">
# <h2>광고 영역</h2>
# <div class="area_ad01" id="ad_layer1"></div>
# <div class="area_ad02" id="ad_layer2">
# </div>
# <div class="area_adual">
# <div class="area_ad03">
# </div>
# <div class="area_ad04">
# </div>
# </div>
# <div class="area_ad05 nHide" id="leftAd05Cj">
# <a href="http://talkon.nate.com/service.html" onmousedown="nc('NBI11');" target="_blank"><img alt="게임할땐 토크온!" height="110" src="//main.nateimg.co.kr/img/v6/talkon_55x110.gif" width="55"/></a>
# </div>
# <div class="area_ad06"></div>
# <div class="area_sktad02"></div>
# <div id="ad_layer3"></div>
# <div id="ad_layer4" style="display:none;"></div>
# </div>
# </div>
# <div id="cbContainer">
# <div class="area_ad08" id="cbLayer" style="display: none">
# <span class="commTxt">한눈에 보는 오늘 <em>NATE</em>와 함께 하루를 시작하세요.</span>
# <a href="javascript:;" id="cbLayerLink" title="NATE를 시작페이지로">NATE를 시작페이지로</a>
# </div>
# </div>
# </div>
# <div class="setting_moblie" id="plus_footer" style="display: none"></div>
# <span id="layerTemp"></span>
# <script src="/js/common/natead_081.js?v=20200206_02" type="text/javascript"></script>
# <script type="text/javascript">
#
# 	if (isiPad) {
# 		document.write('<img src="//stat.nate.com/stat/stat.tiff?cp_url=[www_ndr.nate.com/ipad/]" width="0"  height="0" border="0" alt="" />');
# 	}
#
# </script>
# <script type="text/javascript">
# //<![CDATA[
# try{
#
# 	var contentsUpperTabMenu = ["null", "http://pann.news.nate.com/info", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_gray.gif", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_black.gif" ];
# 	var contentsUpperTopLink = [["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"]];
# 	var contentsUpperSecondPannTitle = ["톡커들의 선택"];
#
# }catch (e) { }
# //]]>
# </script>
# <!--natemain-->
# <script type="text/javascript">//<![CDATA[
#  CFN_type = ''; CFN_id = ''; CFN_cn = ''; CFN_cmn = ''; CFN_link = ''; CFN_link_id = ''; id = (CFN_type == 'N') ? CFN_id : CFN_link_id; cyid = (CFN_type == 'C') ? CFN_id : CFN_link_id; name = CFN_cn; isEmpas = ('' == '1'); refererDomain = ''; CFN_cust_tp_cd = ''; CFN_sex_cd = ''; loginType = ''; isMobile = 'F'; CFN_link_cust_tp_cd = ''; CFN_link_stat_cd = ''; var ndrLoginStatus = (isNateLogin) ? 'login' : ((bLogout) ? 'byebye' : 'logout'); try { divReferer(refererDomain); } catch (e) { } try { if (isNateLogin) fillPersonInfo();} catch (e) { } pageEnd('', '/');//]]>
# </script></body></html>

# %%
import bs4
# r 읽기모드 t 텍스트 드드
webPage = open('Sample02.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')
print(bsObject)
# find로 찾는다. (div태그를)
#tag_div = bsObject.find('div')
#print(tag_div)
# Out:
# <html>
# <head>
# </head>
# <body>
# <div> 요기를 클릭하세요 </div>
# <ul>
# <li> 한빛출판네트워크 </li>
# <li> 비기너 </li>
# <li> 데이터 분석 </li>
# </ul>
# </body>
# </html>

# %%
import bs4
webPage = open('Sample02.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')
tag_ul= bsObject.find('ul')
print(tag_ul)
print()
tag_li= bsObject.find('li')
print(tag_li)
print()
print()
# 리스트 형식으로 저장
tag_li_all= bsObject.findAll('li')
print(tag_li_all)
# Out:
# <ul>
# <li> 한빛출판네트워크 </li>
# <li> 비기너 </li>
# <li> 데이터 분석 </li>
# </ul>
#
# <li> 한빛출판네트워크 </li>
#
#
# [<li> 한빛출판네트워크 </li>, <li> 비기너 </li>, <li> 데이터 분석 </li>]

# %%
import bs4
#bsObject.find('태그명', {'속성명' : '속성값'})
#bsObject.findAll('태그명', {'속성명' : '속성값'})

webPage = open('Sample03.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.find('div', {'id':'myId1'})
print(tag)
tag = bsObject.find('div', {'class':'myClass1'})
print(tag)
tag = bsObject.findAll('div', {'class':'myClass1'})
print(tag)
# Out:
# <div id="myId1"> 아기공룡 </div>
# <div class="myClass1"> 내 친구 </div>
# [<div class="myClass1"> 내 친구 </div>, <div class="myClass1"> 둘리 </div>]

# %%
import bs4
webPage= open('Sample03.html', 'rt', encoding='utf-8').read()
bsObject= bs4.BeautifulSoup(webPage, 'html.parser')

ul_value= bsObject.find('ul', {'class':'myClass2'})
print(ul_value)
print()

li_list= bsObject.findAll('li', {'class':'myClass3'})
print(li_list)
# Out:
# <ul class="myClass2">
# <li> 한빛아카데미 </li>
# <li> 한빛미디어 </li>
# </ul>
#
# [<li class="myClass3"> 비기너 </li>, <li class="myClass3"> 시리즈 </li>]

# %%
import bs4

webPage = open('Sample03.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

a_list = bsObject.findAll('a')
for aTag in a_list :
    print( aTag['href'] )
# Out:
# www.daum.net
# www.nate.com
# www.naver.com

# %%
import bs4

webPage = open('Sample02.html', 'rt', encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')
# 두개 모두 같은 방법인데 다르게 표현
tag_li_all= bsObject.findAll('li')
for tag_li in tag_li_all :
    print(tag_li.text)
    
print()
for i in range(len(tag_li_all)) :
    print(tag_li_all[i].text)

# %%
import bs4
import urllib.request

nateUrl = "https://www.nate.com"
htmlObject = urllib.request.urlopen(nateUrl)
webPage = htmlObject.read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

tag = bsObject.find('div', {'id':'NateBi'})
print(tag , '\n')

a_tag = tag.find("a")
print(a_tag , '\n')

href = a_tag['href']
print( href , '\n')

text = a_tag.text
print(text)
# Out:
# <div class="area_bi" id="NateBi" role="banner">
# <h1 class="bi" title="네이트"><a href="//www.nate.com/?f=bi" onmousedown="nc('NBI01');">네이트</a></h1>
# </div>
#
# <a href="//www.nate.com/?f=bi" onmousedown="nc('NBI01');">네이트</a>
#
# //www.nate.com/?f=bi
#
# 네이트

# %% [markdown]
# # 웹크롤링 실습

# %%
import bs4
import urllib.request

inhaUrl = "https://sports.news.naver.com/index.nhn"
htmlObject = urllib.request.urlopen(inhaUrl)
webPage = htmlObject.read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

li_list = bsObject.find_all('li')
for li in li_list:
    print(li.text, end=' ')
# Out:
#  '하든-레너드가 해냈다! ' 클리퍼스, 벼랑 끝에서 생존…시리즈는 7차전으로
#
#
# 							[점프볼=이규빈 기자] 하든과 레너드가 클리퍼스를 벼랑 끝에서 구했다.LA 클리퍼스는 2일(한국시간) 미국 캘리포니아주 로스앤젤레스 인튜이트 돔에서 열린 2..."
#
#
# 점프볼
# NBA
#
#
#
#
#
#
#
#
#
#
# 대수비로 나선 이정후, 1타수 무안타 '침묵'→타율 0. 316 소폭 하락… 팀도 3연패 수렁
#
#
# 							[스타뉴스 | 박수진 기자] 더그아웃에서 경기를 지켜보고 있는 이정후. /AFPBBNews=뉴스1타격하는 이정후. /AFPBBNews=뉴스1이정후(27·샌프..."
#
#
# 스타뉴스
# 메이저리그
#
#
#
#
#
#
#
#
#
#
# 얄미운 '마황 엉덩이에 니킥' 날린 3루수 '팀 실점의 8할' 주구장창 괴롭히니…
#
#
# 							9회초 1사 후 볼넷으로 출루한 황성빈이 2루 도루를 성공시켰다. 이어 고승민의 유격수 땅볼 때 3루까지 진루했다. 계속된 슬라이딩에 유니폼이 흙투성이가 됐..."
#
#
# 스포츠조선
# KBO리그
#
#
#
#
#
#
#
#
#
#
# '폰와류엄문' 한화 선발 5인방, 강한데 심지어 끈끈하다…'실력+케미' 이상적 시너지
#
#
# 							(엑스포츠뉴스 조은혜 기자) 한화 이글스의 선발 5인방이 든든하게 마운드를 지키며 팀의 중심을 잡고 있다. 개개인의 기량도 뛰어나지만, 5명의 케미스트리 또..."
#
#
# 엑스포츠뉴스
# KBO리그
#
#
#
#
#
#
#
#
#
#
# 이럴 수가! 바이에른, 日에게 날벼락…역대 최악의 수비수 확정? →"김민재 경쟁자 2026년까지 복귀 불투명"
#
#
# 							사진=이토 SNS 캡처로이터연합뉴스로이터연합뉴스[스포츠조선 이현석 기자]바이에른 뮌헨 수비수 이토 히로키의 복귀가 올해 안에 이뤄지기 어려울 수도 있을 전망..."
#
#
# 스포츠조선
# 분데스리가
#
#
#
#
#
#
#
#
#
#
#
#
# '大충격' 콘테-무리뉴 실패 토트넘, 브라질 거절 안첼로티 감독 원한다! … 포스텍 후임으로 명장 고려
#
#
# 							[사진] ⓒGettyimages(무단전재 및 재배포 금지) [사진] ⓒGettyimages(무단전재 및 재배포 금지)[OSEN=우충원 기자] 토트넘이 차기 ..."
#
#
# OSEN
# 프리미어리그
#
#
#
#
#
#
# 1위
# 재생시간00:17
#
#
#
#
# '구급차'까지 등장... 숙연해진 경기장
#
#
#
#
# 2위
# 재생시간00:15
#
#
#
#
# 야구에서 '기적'이라고 부르는 장면....
#
#
#
#
# 3위
# 재생시간00:38
#
#
#
#
# 감독님 할말없게 만드는 황성빈 내야안타 성공
#
#
#
#
# 4위
# 재생시간00:19
#
#
#
#
# 배트맞고 배트가 머리를 쳤지만 위험했쥬
#
#
#
#
# 5위
# 재생시간00:13
#
#
#
#
# 모두를 당황시킨 '빵 터진 시구' ㅋㅋㅋㅋ
#
#
#
#
# 6위
# 재생시간00:10
#
#
#
#
# 실제 프로 '변화구' 초고속 카메라로 보면?
#
#
#
#
# 7위
# 재생시간00:11
#
#
#
#
# 야구장이 이렇게 설레는 곳이야?ㅋㅋ
#
#
#
#
# 8위
# 재생시간00:16
#
#
#
#
# '비거리 144M' MLB급 홈런 친 강백호
#
#
#
#
# 9위
# 재생시간00:12
#
#
#
#
# '얼마나 치겠어...?' 역대급 반전 실력
#
#
#
#
# 10위
# 재생시간00:15
#
#
#
#
# 입이 떡 벌어지는 일반인 광속구 시구...
#
#
#
#
# 11위
# 재생시간00:12
#
#
#
#
# 감독도 깜짝 놀란 미친 주루플레이ㄷㄷ
#
#
#
#
# 12위
# 재생시간00:12
#
#
#
#
# 중국 수비진을 두번 죽인 손흥민 환상 개인기
#
#
#
#
# 13위
# 재생시간00:23
#
#
#
#
# 양의지가 공을 맞았는데 황재균이 웃는다?
#
#
#
#
# 14위
# 재생시간00:14
#
#
#
#
# 헤드샷에 구급차 등장... 침묵의 경기장
#
#
#
#
# 15위
# 재생시간00:15
#
#
#
#
# 여보 대구 가자며
#
#
#
#
# 16위
# 재생시간00:11
#
#
#
#
# 경기 중 몰래 '예능 찍는 상황' ㅋㅋㅋㅋㅋ
#
#
#
#
# 17위
# 재생시간00:12
#
#
#
#
# 아찔한 대형사고 무슨 날벼락이야
#
#
#
#
# 18위
# 재생시간00:10
#
#
#
#
# 실제 '프로 야구선수' 공을 치기 힘든 이유
#
#
#
#
# 19위
# 재생시간00:10
#
#
#
#
# '세계 최초' 번트를 번트 ㅋㅋㅋㅋㅋㅋ
#
#
#
#
# 20위
# 재생시간00:15
#
#
#
#
# 이제는 포수도 약올리는 황성빈?ㅋㅋㅋ
#
#
#
#
#
#
#
#
# 5.01. KBO리그 키움 vs 롯데
#
#
#
#
#
#
#
#
# 5.01. 메이저리그 샌디에이고 vs 샌프란시스코
#
#
#
#
#
#
#
#
# 5.01. KBO리그 두산 vs KT
#
#
#
#
#
#
#
#
# 5.01. KBO리그 SSG vs 삼성
#
#  홈 야구 해외야구 축구 해외축구 농구 배구 N골프 일반 e스포츠

# %%
import csv
import time
import datetime

csvName = 'datetime.csv'
with open(csvName, 'w', newline='') as csvFp:
    csvWriter = csv.writer(csvFp)
    csvWriter.writerow(['연월일', '시분초'])

count = 10
while count > 0:
    count -= 1
    now = datetime.datetime.now()
    yymmdd = now.strftime('%Y-%m-%d')
    hhmmss = now.strftime('%H:%M:%S')
    time_list = [yymmdd, hhmmss]
    print(time_list)
# Out:
# ['2025-05-02', '14:02:03']
# ['2025-05-02', '14:02:03']
# ['2025-05-02', '14:02:03']
# ['2025-05-02', '14:02:03']
# ['2025-05-02', '14:02:03']
# ['2025-05-02', '14:02:03']
# ['2025-05-02', '14:02:03']
# ['2025-05-02', '14:02:03']
# ['2025-05-02', '14:02:03']
# ['2025-05-02', '14:02:03']

# %%
import csv
import time
import datetime
import bs4
import urllib.request
csvName= 'seoul_weather.csv'
with open(csvName, 'w', newline='') as csvFp:
    csvWriter= csv.writer(csvFp)
    csvWriter.writerow(['연월일', '시분초', '온도', '습도', '강수량', '풍향'])
nateUrl= "https://news.nate.com/weather?areaCode=11B10101r"
while True :
    htmlObject= urllib.request.urlopen(nateUrl)
    webPage= htmlObject.read()
    bsObject= bs4.BeautifulSoup(webPage, 'html.parser')
    tag = bsObject.find('div', {'class': 'right_today'})
    temper = tag.find('p', {'class': 'celsius'}).text
    humi= tag.find('p', {'class': 'humidity'}).text
    rain = tag.find('p', {'class': 'rainfall'}).text
    wind = tag.find('p', {'class': 'wind'}).text    
    now = datetime.datetime.now()
    yymmdd= now.strftime('%Y-%m-%d')
    hhmmss= now.strftime('%H:%M:%S')
    weather_list= [yymmdd, hhmmss, temper, humi, rain, wind]
    with open(csvName, 'a', newline='') as csvFp:
        csvWriter= csv.writer(csvFp)
        csvWriter.writerow(weather_list)
    time.sleep(3600)#1시간
